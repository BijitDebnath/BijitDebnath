# %% [markdown]
# <a href="https://colab.research.google.com/github/BijitDebnath/BijitDebnath/blob/main/Recipe_Ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import pandas as pd

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("recipes.csv")
# Out:
#      <input type="file" id="files-4f8d2816-b198-488e-85e2-7b0094cfe612" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f8d2816-b198-488e-85e2-7b0094cfe612">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'recipe_name', 'prep_time', 'cook_time', 'total_time',
#        'servings', 'yield', 'ingredients', 'directions', 'rating', 'url',
#        'cuisine_path', 'nutrition', 'timing', 'img_src'],
#       dtype='object')

# %%
df_1 = df[['recipe_name','ingredients','directions']]

# %%
df_1
# Out:
#                             recipe_name  \
# 0              Apple-Cranberry Crostada
# 1             Apple Pie by Grandma Ople
# 2           Sarah's Homemade Applesauce
# 3                           Apple Crisp
# 4                     Apple Pie Filling
# ...                                 ...
# 1085                     Date-Nut Balls
# 1086                       Jamaica Cake
# 1087                     Best Hot Sauce
# 1088               Moist Date Nut Bread
# 1089  Chef John's Chocolate Energy Bars
#
#                                             ingredients  \
# 0     3 tablespoons butter, 2 pounds Granny Smith ap...
# 1     8 small Granny Smith apples, or as needed, ½ c...
# 2     4  apples - peeled, cored and chopped, ¾ cup w...
# 3     10 cups all-purpose apples, peeled, cored and ...
# 4     18 cups thinly sliced apples, 3 tablespoons le...
# ...                                                 ...
# 1085  14 tablespoons butter, 1 cup pitted chopped da...
# ...

# %%
df_1.to_csv('cleaned_recipes.csv',index=False)

# %%
import pandas as pd

df = pd.read_csv('recipes.csv')

def format_row(row):
    return f"Recipe Name: {row['recipe_name']}\nIngredients: {row['ingredients']}\nDirections: {row['directions']}"

df['formatted_text'] = df.apply(format_row, axis=1)

df['formatted_text'].to_csv('formatted_recipes.txt', index=False, header=False)

# %%
# !pip install datasets

# %%
import torch
from transformers import (
    GPT2LMHeadModel,
    GPT2Tokenizer,
    Trainer,
    TrainingArguments
)
from datasets import load_dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model_name = "gpt2-medium"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
model.to(device)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# ...

# %%
tokenizer.add_special_tokens({"pad_token": "[PAD]"})
model.resize_token_embeddings(len(tokenizer))
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(50258, 1024)

# %%
# !pip install datasets

# %%
import torch
from torch.utils.data import Dataset

class RecipeDataset(Dataset):
    def __init__(self, file_path, tokenizer, block_size=256):
        with open(file_path, encoding="utf-8") as f:
            lines = f.readlines()

        self.examples = []

        for line in lines:
            tokens = tokenizer(
                line,
                truncation=True,
                padding="max_length",
                max_length=block_size,
                return_tensors="pt"
            )
            self.examples.append(tokens["input_ids"][0])

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        return {
            "input_ids": self.examples[idx],
            "labels": self.examples[idx],
        }

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=5,
    per_device_train_batch_size=2,
    save_strategy="steps",
    save_steps=1000,
    save_total_limit=2,
    logging_steps=100,
    report_to="none"
)

# %%
import pandas as pd

df = pd.read_csv("cleaned_recipes.csv")

df["full_recipe"] = df["ingredients"] + " " + df["directions"]

df["full_recipe"].to_csv("cleaned_recipes.txt",
                         index=False,
                         header=False)

# %%
train_dataset = RecipeDataset("cleaned_recipes.txt", tokenizer)

# %%
print("model" in globals())
print("train_dataset" in globals())
print("data_collator" in globals())
print("training_args" in globals())
# Out:
# True
# True
# True
# True

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='2240' max='17885' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2240/17885 16:38 < 1:56:18, 2.24 it/s, Epoch 0.63/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.773771</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.674016</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.785518</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.833836</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.538544</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.851627</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.364651</td>
#     </tr>
#     <tr>
# ...

# %%
model.save_pretrained("./trained_model")
tokenizer.save_pretrained("./trained_model")

print("model and tokenizer saved")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# model and tokenizer saved

# %%
model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50258, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=3072, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=1024)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=4096, nx=1024)
#           (c_proj): Conv1D(nf=1024, nx=4096)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
# ...

# %%
import torch

# Define prompt and tokenize it to create 'inputs' for demonstration
prompt = "Ingredients: dates,butter,oil\nRecipe:"
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)


print(model.device)
print(inputs["input_ids"].device)
# Out:
# cuda:0
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

save_path = "/content/drive/MyDrive/RecipeGPT_Model"

os.makedirs(save_path, exist_ok=True)

# %%
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)

print("Model saved to Drive successfully!")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved to Drive successfully!

# %%
import torch

model.eval()

prompt = "Ingredients: dates,butter,oil\nRecipe:"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    output = model.generate(
        **inputs,
        max_length=200,
        temperature=0.8,
        top_k=50,
        top_p=0.95,
        repetition_penalty=1.3,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# Ingredients: dates,butter,oil
# Recipe: Mix together the flour and baking powder in a medium bowl. Gradually add oats,milk mixture to an even layer; mix until evenly moistened with date paste."
# 9  half pint canning jars or storage containers With lids on Prepare according as directed by package directions."The filling will be very thick. Fold parchment paper over top of filling so it's almost falling off the pie.
# 16 ounces miniature marshmallows Invert onto serving platter Place filling into prepared jars or containers and screw rings on tightly (lid does not move up nor down at all).
# 10  chocolate sprinkles Preheat oven broiler for high heat.
# 12 cups low-fat evaporated milk Combine evaporating milkside dishwith foil in pan in oven preheats. Broil 15 minutes while filling is cooling before slicing. Let cool completely. Store in an airtight container frozen when done - thawed overnight, 8 hours

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

load_path = "/content/drive/MyDrive/RecipeGPT_Model"

tokenizer = GPT2Tokenizer.from_pretrained(load_path)
model = GPT2LMHeadModel.from_pretrained(load_path)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

print("Model loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# Model loaded successfully!

# %%
user_ingredients = input("Enter ingredients: ")

prompt = f"""Recipe:

Ingredients:
{user_ingredients}

Instructions:
"""

inputs = tokenizer(prompt, return_tensors="pt").to(device)

with torch.no_grad():
    output = model.generate(
        **inputs,
        max_length=250,
        temperature=0.7,
        top_k=40,
        top_p=0.9,
        repetition_penalty=1.2,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Enter ingredients: chicken,rice,onion
# Recipe:
#
# Ingredients:
# chicken,rice,onion
#
# Instructions:
# 1  red onion, thinly sliced and cut into 1/2-inch rounds , 3 tablespoons extra virgin olive oil cooking spray Preheat an outdoor grill for medium heat. Lightly oil the grate. Brown the onions in hot oil, turning to brown all sides except where charred black on one side (see Editor's Note). Transfer cooked bits onto a paper towel-lined plate; season with salt and pepper. Grill until golden brown on both sides without discarding chunks left behind after roasting or cutting into strips of caramelized onion meal that fall apart when heated through, about 15 minutes."
# ...
